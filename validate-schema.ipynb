# %%
from jsonschema import validate
import simplejson as json

# %%
with open("schemas/definition.schema.json", 'r') as f:
    schema_data = f.read()
schema = json.loads(schema_data)

with open("example.json", "r") as f:
    example_data = f.read()
example = json.loads(example_data)    



validate(example, schema)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/validators.py in resolve_from_url(self, url)
#     738         try:
# --> 739             document = self.store[url]
#     740         except KeyError:
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/_utils.py in __getitem__(self, uri)
#      22     def __getitem__(self, uri):
# ---> 23         return self.store[self.normalize(uri)]
#      24
#
# KeyError: 'https://raw.githubusercontent.com/valeriy42/evaluation-schema/master/schemas/input2.schema.json'
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/validators.py in resolve_from_url(self, url)
#     741             try:
# --> 742                 document = self.resolve_remote(url)
#     743             except Exception as exc:
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/validators.py in resolve_remote(self, uri)
#     827             # Otherwise, pass off to urllib and assume utf-8
# --> 828             with urlopen(uri) as url:
#     829                 result = json.loads(url.read().decode("utf-8"))
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 404: Not Found
#
# During handling of the above exception, another exception occurred:
#
# RefResolutionError                        Traceback (most recent call last)
# <ipython-input-42-a39865a3abea> in <module>
#       9
#      10
# ---> 11 validate(example, schema)
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/validators.py in validate(instance, schema, cls, *args, **kwargs)
#     895     cls.check_schema(schema)
#     896     validator = cls(schema, *args, **kwargs)
# --> 897     error = exceptions.best_match(validator.iter_errors(instance))
#     898     if error is not None:
#     899         raise error
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/exceptions.py in best_match(errors, key)
#     291 def best_match(errors, key=relevance):
#     292     errors = iter(errors)
# --> 293     best = next(errors, None)
#     294     if best is None:
#     295         return
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/validators.py in iter_errors(self, instance, _schema)
#     321
#     322                     errors = validator(self, v, instance, _schema) or ()
# --> 323                     for error in errors:
#     324                         # set details if not already set by the called fn
#     325                         error._set(
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/_validators.py in properties(validator, properties, instance, schema)
#     284                 subschema,
#     285                 path=property,
# --> 286                 schema_path=property,
#     287             ):
#     288                 yield error
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/validators.py in descend(self, instance, schema, path, schema_path)
#     337
#     338         def descend(self, instance, schema, path=None, schema_path=None):
# --> 339             for error in self.iter_errors(instance, schema):
#     340                 if path is not None:
#     341                     error.path.appendleft(path)
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/validators.py in iter_errors(self, instance, _schema)
#     321
#     322                     errors = validator(self, v, instance, _schema) or ()
# --> 323                     for error in errors:
#     324                         # set details if not already set by the called fn
#     325                         error._set(
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/_validators.py in ref(validator, ref, instance, schema)
#     257                 yield error
#     258     else:
# --> 259         scope, resolved = validator.resolver.resolve(ref)
#     260         validator.resolver.push_scope(scope)
#     261
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/validators.py in resolve(self, ref)
#     732     def resolve(self, ref):
#     733         url = self._urljoin_cache(self.resolution_scope, ref)
# --> 734         return url, self._remote_cache(url)
#     735
#     736     def resolve_from_url(self, url):
#
# ~/anaconda3/envs/jasonschema/lib/python3.7/site-packages/jsonschema/validators.py in resolve_from_url(self, url)
#     742                 document = self.resolve_remote(url)
#     743             except Exception as exc:
# --> 744                 raise exceptions.RefResolutionError(exc)
#     745
#     746         return self.resolve_fragment(document, fragment)
#
# RefResolutionError: HTTP Error 404: Not Found

# %% [markdown]
# pre-processing: [
# {"one_hot_encoding": {"field": "fieldName", "hot_map":{CODING_MAP}}},
# {"one_hot_encoding": {"field": "fieldName2", "hot_map":{CODING_MAP}}}
# ]
